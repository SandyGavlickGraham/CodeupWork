# %% [markdown]
# Create a file named perpare_mall.py that contains functions that do the following:
#
# - detects any outliers
# - encodes all the categorical columns, and adds the encoded column (i.e. it doesn't remove the original column)
# - accepts the unprepared mall customers data frame and applies all the transformations above

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from acquire_mall import get_mall_customer_data 
from summarize import df_summary

# %%
def get_outliers(s, k):
    '''
    Given a series and a cutoff value, k, returns the upper outliers for the
    series.

    The values returned will be either 0 (if the point is not an outlier), or a
    number that indicates how far away from the upper bound the observation is.
    '''
    q1, q3 = s.quantile([.25, .75])
    iqr = q3 - q1
    upper_bound = q3 + k * iqr
    lower_bound = q3 - k * iqr
    upper = s.apply(lambda x: max([x - upper_bound, 0]))
    lower = s.apply(lambda x: min([x + lower_bound, 0]))
    return (upper,lower)

# %%
def add_outlier_columns(df, k):
    '''
    Add a column with the suffix _outliers for all the numeric columns
    in the given dataframe.
    '''
   # make a copy of the df to avoid possible side-affects
    df = df.copy()
    
    for col in df.select_dtypes('number'):
        upper, lower = get_outliers(df[col], k)
        df[col + '_upper_outliers'] = upper
        df[col + '_lower_outliers'] = lower

    return df

# %%
# # get the mall data and set the customer_id as the index
# mall_df = get_mall_customer_data()
# mall_df.set_index('customer_id', inplace=True)
# print(mall_df.dtypes)
# print(mall_df.head(3).append(mall_df.tail(3)))

# %%
# # Add the columns for the outliers
# mall_df = add_outlier_columns(mall_df, k=1.5)
# mall_df.head(3).append(mall_df.tail(3))

# %%
# # create two columns for male and female respectively
# dummy = pd.get_dummies(mall_df['gender'])
# df = pd.concat((mall_df, dummy), axis=1)
# df.head(3)

# %% [markdown]
# Summarize
# 1. Write or use a previous function you have written that summarizes the data you have just read into a dataframe in the ways we have discussed in previous modules (sample view, datatypes, value counts, summary stats, ...)
# 2. Use this function from a notebook to get an overview of your data.
# 3. Use this function to help when you are working with the zillow data as well.

# %%
# df_summary(df)

# %%
def prep_mall_data(mall_df):
    mall_df = mall_df.copy()
    mall_df.set_index('customer_id', inplace=True)
    print(mall_df.dtypes)
    print(mall_df.head(3).append(mall_df.tail(3)))
    # Add the columns for the outliers
    mall_df = add_outlier_columns(mall_df, k=1.5)
    mall_df.head(3).append(mall_df.tail(3))
    # create two columns for male and female respectively
    dummy = pd.get_dummies(mall_df['gender'])
    df = pd.concat((mall_df, dummy), axis=1)
    df.head(3)
    df_summary(df)
    return df

# %%
if __name__ == '__main__':
    mall_df = get_mall_customer_data()
    mall_df = prep_mall_data(mall_df)
# Out:
# gender            object
# age                int64
# annual_income      int64
# spending_score     int64
# dtype: object
#              gender  age  annual_income  spending_score
# customer_id
# 1              Male   19             15              39
# 2              Male   21             15              81
# 3            Female   20             16               6
# 198            Male   32            126              74
# 199            Male   32            137              18
# 200            Male   30            137              83
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# --- Top and Bottom:
# Sorted by gender:
# Head:
# customer_id     70      97      161
# gender       Female  Female  Female
#
# Tail:
# customer_id   78    139   200
# gender       Male  Male  Male
# -----
# Sorted by age:
# Head:
# customer_id  115  92   66
# age           18   18   18
#
# Tail:
# customer_id  58  71  61
# age          69  70  70
# -----
# Sorted by annual_income:
# Head:
# customer_id     1   2   3
# annual_income  15  15  16
#
# Tail:
# customer_id    198  199  200
# annual_income  126  137  137
# -----
# Sorted by spending_score:
# Head:
# customer_id     157  159  9
# spending_score    1    1    3
#
# Tail:
# customer_id     186  20   12
# spending_score   97   98   99
# -----
# Sorted by age_upper_outliers:
# Head:
# customer_id         1    128  129
# age_upper_outliers    0    0    0
#
# Tail:
# customer_id         73   63   200
# age_upper_outliers    0    0    0
# -----
# Sorted by age_lower_outliers:
# Head:
# customer_id         1    128  129
# age_lower_outliers    0    0    0
#
# Tail:
# customer_id         73   63   200
# age_lower_outliers    0    0    0
# -----
# Sorted by annual_income_upper_outliers:
# Head:
# customer_id                   1    128  129
# annual_income_upper_outliers  0.0  0.0  0.0
#
# Tail:
# customer_id                   63    199   200
# annual_income_upper_outliers  0.0  4.25  4.25
# -----
# Sorted by annual_income_lower_outliers:
# Head:
# customer_id                   1    128  129
# annual_income_lower_outliers    0    0    0
#
# Tail:
# customer_id                   73   63   200
# annual_income_lower_outliers    0    0    0
# -----
# Sorted by spending_score_upper_outliers:
# Head:
# customer_id                    1    128  129
# spending_score_upper_outliers    0    0    0
#
# Tail:
# customer_id                    73   63   200
# spending_score_upper_outliers    0    0    0
# -----
# Sorted by spending_score_lower_outliers:
# Head:
# customer_id                    1    128  129
# spending_score_lower_outliers    0    0    0
#
# Tail:
# customer_id                    73   63   200
# spending_score_lower_outliers    0    0    0
# -----
# Sorted by Female:
# Head:
# customer_id  1    129  128
# Female         0    0    0
#
# Tail:
# customer_id  113  125  64
# Female         1    1    1
# -----
# Sorted by Male:
# Head:
# customer_id  70   97   161
# Male           0    0    0
#
# Tail:
# customer_id  78   139  200
# Male           1    1    1
# -----
# None
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# --- Shape:
# (200, 12)
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# --- Info:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 1 to 200
# Data columns (total 12 columns):
# gender                           200 non-null object
# age                              200 non-null int64
# annual_income                    200 non-null int64
# spending_score                   200 non-null int64
# age_upper_outliers               200 non-null int64
# age_lower_outliers               200 non-null int64
# annual_income_upper_outliers     200 non-null float64
# annual_income_lower_outliers     200 non-null int64
# spending_score_upper_outliers    200 non-null int64
# spending_score_lower_outliers    200 non-null int64
# Female                           200 non-null uint8
# Male                             200 non-null uint8
# dtypes: float64(1), int64(8), object(1), uint8(2)
# memory usage: 17.6+ KB
# None
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# --- Check if all ftypes are dense:
#
# A sparse array is one that contains mostly zeros and few non-zero
# entries. A dense array contains mostly non-zeros.
# int64:dense      8
# uint8:dense      2
# object:dense     1
# float64:dense    1
# dtype: int64
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# --- Descriptions:
#         gender         age  annual_income  spending_score  age_upper_outliers  \
# count      200  200.000000     200.000000      200.000000               200.0
# unique       2         NaN            NaN             NaN                 NaN
# top     Female         NaN            NaN             NaN                 NaN
# freq       112         NaN            NaN             NaN                 NaN
# mean       NaN   38.850000      60.560000       50.200000                 0.0
# std        NaN   13.969007      26.264721       25.823522                 0.0
# min        NaN   18.000000      15.000000        1.000000                 0.0
# 25%        NaN   28.750000      41.500000       34.750000                 0.0
# 50%        NaN   36.000000      61.500000       50.000000                 0.0
# 75%        NaN   49.000000      78.000000       73.000000                 0.0
# max        NaN   70.000000     137.000000       99.000000                 0.0
#
#         age_lower_outliers  annual_income_upper_outliers  \
# count                200.0                    200.000000
# unique                 NaN                           NaN
# top                    NaN                           NaN
# freq                   NaN                           NaN
# mean                   0.0                      0.042500
# std                    0.0                      0.423931
# min                    0.0                      0.000000
# 25%                    0.0                      0.000000
# 50%                    0.0                      0.000000
# 75%                    0.0                      0.000000
# max                    0.0                      4.250000
#
#         annual_income_lower_outliers  spending_score_upper_outliers  \
# count                          200.0                          200.0
# unique                           NaN                            NaN
# top                              NaN                            NaN
# freq                             NaN                            NaN
# mean                             0.0                            0.0
# std                              0.0                            0.0
# min                              0.0                            0.0
# 25%                              0.0                            0.0
# 50%                              0.0                            0.0
# 75%                              0.0                            0.0
# max                              0.0                            0.0
#
#         spending_score_lower_outliers      Female        Male
# count                           200.0  200.000000  200.000000
# unique                            NaN         NaN         NaN
# top                               NaN         NaN         NaN
# freq                              NaN         NaN         NaN
# mean                              0.0    0.560000    0.440000
# std                               0.0    0.497633    0.497633
# min                               0.0    0.000000    0.000000
# 25%                               0.0    0.000000    0.000000
# 50%                               0.0    1.000000    0.000000
# 75%                               0.0    1.000000    1.000000
# max                               0.0    1.000000    1.000000
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# ---Nulls By Columns:
#                                num_missing  missing_percentage  num_empty  \
# gender                                   0                 0.0          0
# age                                      0                 0.0          0
# annual_income                            0                 0.0          0
# spending_score                           0                 0.0          0
# age_upper_outliers                       0                 0.0          0
# age_lower_outliers                       0                 0.0          0
# annual_income_upper_outliers             0                 0.0          0
# annual_income_lower_outliers             0                 0.0          0
# spending_score_upper_outliers            0                 0.0          0
# spending_score_lower_outliers            0                 0.0          0
# Female                                   0                 0.0          0
# Male                                     0                 0.0          0
#
#                                empty_percentage  nan_count  nan_percentage
# gender                                      0.0          0             0.0
# age                                         0.0          0             0.0
# annual_income                               0.0          0             0.0
# spending_score                              0.0          0             0.0
# age_upper_outliers                          0.0          0             0.0
# age_lower_outliers                          0.0          0             0.0
# annual_income_upper_outliers                0.0          0             0.0
# annual_income_lower_outliers                0.0          0             0.0
# spending_score_upper_outliers               0.0          0             0.0
# spending_score_lower_outliers               0.0          0             0.0
# Female                                      0.0          0             0.0
# Male                                        0.0          0             0.0
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# --- Summary of Nulls by Rows:
#              num_missing  percentage
# customer_id
# 1                      0         0.0
# 2                      0         0.0
# 3                      0         0.0
# 4                      0         0.0
# 5                      0         0.0
# 6                      0         0.0
# 7                      0         0.0
# 8                      0         0.0
# 9                      0         0.0
# 10                     0         0.0
# 11                     0         0.0
# 12                     0         0.0
# 13                     0         0.0
# 14                     0         0.0
# 15                     0         0.0
# 16                     0         0.0
# 17                     0         0.0
# 18                     0         0.0
# 19                     0         0.0
# 20                     0         0.0
# 21                     0         0.0
# 22                     0         0.0
# 23                     0         0.0
# 24                     0         0.0
# 25                     0         0.0
# 26                     0         0.0
# 27                     0         0.0
# 28                     0         0.0
# 29                     0         0.0
# 30                     0         0.0
# ...                  ...         ...
# 171                    0         0.0
# 172                    0         0.0
# 173                    0         0.0
# 174                    0         0.0
# 175                    0         0.0
# 176                    0         0.0
# 177                    0         0.0
# 178                    0         0.0
# 179                    0         0.0
# 180                    0         0.0
# 181                    0         0.0
# 182                    0         0.0
# 183                    0         0.0
# 184                    0         0.0
# 185                    0         0.0
# 186                    0         0.0
# 187                    0         0.0
# 188                    0         0.0
# 189                    0         0.0
# 190                    0         0.0
# 191                    0         0.0
# 192                    0         0.0
# 193                    0         0.0
# 194                    0         0.0
# 195                    0         0.0
# 196                    0         0.0
# 197                    0         0.0
# 198                    0         0.0
# 199                    0         0.0
# 200                    0         0.0
#
# [200 rows x 2 columns]
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# --- amount of missing values in columns:
# Empty DataFrame
# Columns: [total_missing, total_percentage, num_missing, missing_percentage, num_empty, empty_percentage, nan_count, nan_percentage]
# Index: []
