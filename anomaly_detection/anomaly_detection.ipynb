# %% [markdown]
# # Exercises
# file name: anomaly_detection.py or anomaly_detection.ipynb
#
# #### Discrete data + probability
# Use basic probability to identify anomalous request methods. You will want to make sure the text is normalized in order to reduce the noise.
#
# #### Time series + EMA
# Discover users who are accessing our curriculum pages way beyond the end of their codeup time. What would the dataframe look like? Use time series method for detecting anomalies, like exponential moving average with %b.
#
# #### Clustering - DBSCAN
# Use dbscan to detect anomalies in other products from the customers dataset.
#
# Use dbscan to detect anomalies in number of bedrooms and finished square feet of property for the filtered dataset you used in the clustering project (single unit properties with a logerror).

# %% [markdown]
# # %%%%%%%%%%%%%%%%%

# %% [markdown]
# # Anomaly Detection of Discrete Data using Probability
# ## Discrete data + probability
#
# ### Use basic probability to identify anomalous request methods. You will want to make sure the text is normalized in order to reduce the noise.

# %%
from __future__ import division
import itertools
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import pandas as pd
import math
from sklearn import metrics
from random import randint
from matplotlib import style
import seaborn as sns
# %matplotlib inline
from ipaddress import ip_address
import re
import json
from urllib.request import urlopen
import ipinfo

# %% [markdown]
# #### Wrangle Data
# ##### Acquire

# %% [markdown]
# sample data rows:
#
# 2018-01-26 09:55:03 / 1 8 97.105.19.61
#
# 2018-01-26 10:00:02 javascript-i/introduction/working-with-data-types-operators-and-variables 6 22 97.105.19.61
#
# 2018-01-26 10:00:49 javascript-i/introduction/variables 6 22 97.105.19.61

# %%
colnames=['date', 'time', 'stuff', 'id', 'cohort', 'ip_address']
df = pd.read_csv('./anonymized-curriculum-access.txt',          
                 engine='python',
                 header=None,
                 index_col=False,
                 names=colnames,
                 sep=' ',
#                  sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])',
                 na_values='"-"',
#                  usecols=[0, 3, 4, 5, 6, 7, 8]
)

# %%
df.head().append(df.tail())
# Out:
#               date      time  \
# 0       2018-01-26  09:55:03
# 1       2018-01-26  09:56:02
# 2       2018-01-26  09:56:05
# 3       2018-01-26  09:56:06
# 4       2018-01-26  09:56:24
# 233523  2019-04-02  11:10:19
# 233524  2019-04-02  11:11:18
# 233525  2019-04-02  11:11:23
# 233526  2019-04-02  11:11:25
# 233527  2019-04-02  11:11:29
#
#                                                     stuff   id  cohort  \
# 0                                                       /    1     8.0
# 1                                                 java-ii    1     8.0
# 2                     java-ii/object-oriented-programming    1     8.0
# 3                      slides/object_oriented_programming    1     8.0
# 4                               javascript-i/conditionals    2    22.0
# 233523                                java-ii/annotations  329    29.0
# 233524  javascript-i/introduction/working-with-data-ty...  384    31.0
# 233525                                       javascript-i  373    31.0
# 233526  javascript-i/introduction/working-with-data-ty...  376    31.0
# 233527  javascript-i/introduction/working-with-data-ty...  373    31.0
#
#           ip_address
# 0       97.105.19.61
# 1       97.105.19.61
# 2       97.105.19.61
# 3       97.105.19.61
# 4       97.105.19.61
# 233523  97.105.19.58
# 233524  97.105.19.58
# 233525  97.105.19.58
# 233526  97.105.19.58
# 233527  97.105.19.58

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233528 entries, 0 to 233527
# Data columns (total 6 columns):
# date          233528 non-null object
# time          233528 non-null object
# stuff         233528 non-null object
# id            233528 non-null int64
# cohort        219070 non-null float64
# ip_address    233528 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 10.7+ MB

# %%
df.isna().sum()
# Out:
# date              0
# time              0
# stuff             0
# id                0
# cohort        14458
# ip_address        0
# dtype: int64

# %% [markdown]
# Fill missing cohort numbers with 0.

# %%
df.cohort.fillna(0, inplace=True)
df.isna().sum()
# Out:
# date          0
# time          0
# stuff         0
# id            0
# cohort        0
# ip_address    0
# dtype: int64

# %%
df.shape
# Out:
# (233528, 6)

# %%
df.dtypes
# Out:
# date           object
# time           object
# stuff          object
# id              int64
# cohort        float64
# ip_address     object
# dtype: object

# %% [markdown]
# ##### Make the access date the index
# Create a timestamp for the index.

# %%
df['timestamp'] = df.date + ' ' + df.time
df.timestamp = pd.to_datetime(df['timestamp'])
df.head()
# Out:
#          date      time                                stuff  id  cohort  \
# 0  2018-01-26  09:55:03                                    /   1     8.0
# 1  2018-01-26  09:56:02                              java-ii   1     8.0
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming   1     8.0
# 3  2018-01-26  09:56:06   slides/object_oriented_programming   1     8.0
# 4  2018-01-26  09:56:24            javascript-i/conditionals   2    22.0
#
#      ip_address           timestamp
# 0  97.105.19.61 2018-01-26 09:55:03
# 1  97.105.19.61 2018-01-26 09:56:02
# 2  97.105.19.61 2018-01-26 09:56:05
# 3  97.105.19.61 2018-01-26 09:56:06
# 4  97.105.19.61 2018-01-26 09:56:24

# %%
df = df.set_index('timestamp')
df.head()
# Out:
#                            date      time  \
# timestamp
# 2018-01-26 09:55:03  2018-01-26  09:55:03
# 2018-01-26 09:56:02  2018-01-26  09:56:02
# 2018-01-26 09:56:05  2018-01-26  09:56:05
# 2018-01-26 09:56:06  2018-01-26  09:56:06
# 2018-01-26 09:56:24  2018-01-26  09:56:24
#
#                                                    stuff  id  cohort  \
# timestamp
# 2018-01-26 09:55:03                                    /   1     8.0
# 2018-01-26 09:56:02                              java-ii   1     8.0
# 2018-01-26 09:56:05  java-ii/object-oriented-programming   1     8.0
# 2018-01-26 09:56:06   slides/object_oriented_programming   1     8.0
# 2018-01-26 09:56:24            javascript-i/conditionals   2    22.0
#
#                        ip_address
# timestamp
# 2018-01-26 09:55:03  97.105.19.61
# 2018-01-26 09:56:02  97.105.19.61
# 2018-01-26 09:56:05  97.105.19.61
# 2018-01-26 09:56:06  97.105.19.61
# 2018-01-26 09:56:24  97.105.19.61

# %% [markdown]
# ##### Clean up text

# %% [markdown]
# Replace the request paths that have only / with home_page.

# %%
df.replace(regex=r'^/$', value='home_page', inplace=True)

# %%
maxcount = 0
for i, command in enumerate(df.stuff):
    if len(command.split('/')) > maxcount:
        maxcount = len(command.split('/'))
        print('maxcount: ', maxcount)
        print(command)
print('final maxcount is ', maxcount)
# Out:
# maxcount:  1
# home_page
# maxcount:  2
# java-ii/object-oriented-programming
# maxcount:  3
# javascript-i/introduction/working-with-data-types-operators-and-variables
# maxcount:  4
# appendix/further-reading/javascript/hoisting.html
# maxcount:  6
# content/laravel/intro/gitbook/images/favicon.ico
# maxcount:  7
# content/appendix/postwork/basic_challenges/gitbook/images/favicon.ico
# maxcount:  8
# cohorts/%7Bid%7D/grades.csvhttp://tools.codeup.com/cohorts/26/grades.csv
# final maxcount is  8

# %% [markdown]
# This row is clearly an error...

# %%
df[df.stuff == 'cohorts/%7Bid%7D/grades.csvhttp://tools.codeup.com/cohorts/26/grades.csv']
# Out:
#                            date      time  \
# timestamp
# 2019-01-11 11:51:19  2019-01-11  11:51:19
#
#                                                                  stuff  id  \
# timestamp
# 2019-01-11 11:51:19  cohorts/%7Bid%7D/grades.csvhttp://tools.codeup...  64
#
#                      cohort    ip_address
# timestamp
# 2019-01-11 11:51:19    28.0  70.118.8.243

# %%
df = df[df.stuff != 'cohorts/%7Bid%7D/grades.csvhttp://tools.codeup.com/cohorts/26/grades.csv']
df[df.stuff == 'cohorts/%7Bid%7D/grades.csvhttp://tools.codeup.com/cohorts/26/grades.csv']
# Out:
# Empty DataFrame
# Columns: [date, time, stuff, id, cohort, ip_address]
# Index: []

# %%
maxcount = 0
for i, command in enumerate(df.stuff):
    if len(command.split('/')) > maxcount:
        maxcount = len(command.split('/'))
        print('maxcount: ', maxcount)
        print(command)
print('final maxcount is ', maxcount)
# Out:
# maxcount:  1
# home_page
# maxcount:  2
# java-ii/object-oriented-programming
# maxcount:  3
# javascript-i/introduction/working-with-data-types-operators-and-variables
# maxcount:  4
# appendix/further-reading/javascript/hoisting.html
# maxcount:  6
# content/laravel/intro/gitbook/images/favicon.ico
# maxcount:  7
# content/appendix/postwork/basic_challenges/gitbook/images/favicon.ico
# final maxcount is  7

# %% [markdown]
# Take off the page number stuff from the request paths...

# %%
df['stuff'] = df.stuff.str.replace(r'\?page=[0-9]+', '', regex=True)

df.head()
# Out:
#                            date      time  \
# timestamp
# 2018-01-26 09:55:03  2018-01-26  09:55:03
# 2018-01-26 09:56:02  2018-01-26  09:56:02
# 2018-01-26 09:56:05  2018-01-26  09:56:05
# 2018-01-26 09:56:06  2018-01-26  09:56:06
# 2018-01-26 09:56:24  2018-01-26  09:56:24
#
#                                                    stuff  id  cohort  \
# timestamp
# 2018-01-26 09:55:03                            home_page   1     8.0
# 2018-01-26 09:56:02                              java-ii   1     8.0
# 2018-01-26 09:56:05  java-ii/object-oriented-programming   1     8.0
# 2018-01-26 09:56:06   slides/object_oriented_programming   1     8.0
# 2018-01-26 09:56:24            javascript-i/conditionals   2    22.0
#
#                        ip_address
# timestamp
# 2018-01-26 09:55:03  97.105.19.61
# 2018-01-26 09:56:02  97.105.19.61
# 2018-01-26 09:56:05  97.105.19.61
# 2018-01-26 09:56:06  97.105.19.61
# 2018-01-26 09:56:24  97.105.19.61

# %% [markdown]
# Split the request path into sections. Each section will get its own row.

# %%
s = df['stuff'].str.split('/').apply(pd.Series, 1).stack()

s.index = s.index.droplevel(-1) # to line up with df's index

s.name = 'stuff' # needs a name to join

s
# Out:
# timestamp
# 2018-01-26 09:55:03                                          home_page
# 2018-01-26 09:56:02                                            java-ii
# 2018-01-26 09:56:05                                            java-ii
# 2018-01-26 09:56:05                        object-oriented-programming
# 2018-01-26 09:56:06                                             slides
# 2018-01-26 09:56:06                        object_oriented_programming
# 2018-01-26 09:56:24                                       javascript-i
# 2018-01-26 09:56:24                                       conditionals
# 2018-01-26 09:56:41                                       javascript-i
# 2018-01-26 09:56:41                                              loops
# 2018-01-26 09:56:46                                       javascript-i
# 2018-01-26 09:56:46                                       conditionals
# 2018-01-26 09:56:48                                       javascript-i
# 2018-01-26 09:56:48                                          functions
# 2018-01-26 09:56:59                                       javascript-i
# 2018-01-26 09:56:59                                              loops
# 2018-01-26 09:58:26                                       javascript-i
# 2018-01-26 09:58:26                                          functions
# 2018-01-26 09:59:22                                             mkdocs
# 2018-01-26 09:59:22                                  search_index.json
# 2018-01-26 10:00:02                                       javascript-i
# 2018-01-26 10:00:02                                       introduction
# 2018-01-26 10:00:02    working-with-data-types-operators-and-variables
# 2018-01-26 10:00:37                                          home_page
# 2018-01-26 10:00:39                                       javascript-i
# 2018-01-26 10:00:44                                       javascript-i
# 2018-01-26 10:00:44                                       introduction
# 2018-01-26 10:00:44    working-with-data-types-operators-and-variables
# 2018-01-26 10:00:49                                       javascript-i
# 2018-01-26 10:00:49                                       introduction
#                                             ...
# 2019-04-02 11:07:39                                       introduction
# 2019-04-02 11:08:24                                            java-ii
# 2019-04-02 11:08:24                                        annotations
# 2019-04-02 11:08:53                                             java-i
# 2019-04-02 11:08:56                                            java-ii
# 2019-04-02 11:08:58                                            java-ii
# 2019-04-02 11:08:58                      exceptions-and-error-handling
# 2019-04-02 11:09:00                                       javascript-i
# 2019-04-02 11:09:00                               javascript-with-html
# 2019-04-02 11:09:21                                              mysql
# 2019-04-02 11:09:21                                              users
# 2019-04-02 11:09:32                                              mysql
# 2019-04-02 11:09:32                                           intellij
# 2019-04-02 11:09:58                                        6_Exercises
# 2019-04-02 11:10:00                                           java-iii
# 2019-04-02 11:10:00                        deployment-and-dependencies
# 2019-04-02 11:10:13                                          home_page
# 2019-04-02 11:10:17                                            java-ii
# 2019-04-02 11:10:19                                            java-ii
# 2019-04-02 11:10:19                                        annotations
# 2019-04-02 11:11:18                                       javascript-i
# 2019-04-02 11:11:18                                       introduction
# 2019-04-02 11:11:18    working-with-data-types-operators-and-variables
# 2019-04-02 11:11:23                                       javascript-i
# 2019-04-02 11:11:25                                       javascript-i
# 2019-04-02 11:11:25                                       introduction
# 2019-04-02 11:11:25    working-with-data-types-operators-and-variables
# 2019-04-02 11:11:29                                       javascript-i
# 2019-04-02 11:11:29                                       introduction
# 2019-04-02 11:11:29    working-with-data-types-operators-and-variables
# Name: stuff, Length: 478318, dtype: object

# %% [markdown]
# Drop the 'stuff' column before the join.

# %%
df_no_stuff = df.drop(columns = 'stuff')

# %%
df_split = df_no_stuff.join(s.apply(lambda x: pd.Series(x.split('/'))))

# 2019-04-02 11:10:19    97.105.19.58
# 2019-04-02 11:11:18    97.105.19.58
# 2019-04-02 11:11:23    97.105.19.58
# 2019-04-02 11:11:25    97.105.19.58
# 2019-04-02 11:11:29    97.105.19.58
# Name: ip_address, Length: 233527, dtype: object does not appear to be an IPv4 or IPv6 address

# %%
count = 0
try:
    network = ip_address(df.ip_address)
except ValueError:
    count += 1
    print('address/netmask is invalid:', count)
# Out:
# address/netmask is invalid: 1

# %%
df.ip_address.value_counts()
# Out:
# 97.105.19.58       105645
# 97.105.19.61        61662
# 192.171.117.210      5966
# 173.174.211.206      1019
# 66.69.62.219          934
# 72.181.104.64         865
# 216.1.153.162         790
# 67.11.239.2           749
# 66.69.108.117         666
# 170.248.173.245       661
# 67.10.161.55          651
# 70.118.8.243          614
# 70.121.163.5          565
# 76.185.182.91         564
# 76.204.31.63          549
# 24.243.8.81           539
# 72.191.50.176         523
# 173.173.113.51        512
# 108.65.244.91         506
# 173.174.253.193       506
# 170.248.173.247       467
# 104.53.201.99         447
# 68.206.106.64         446
# 76.185.131.226        432
# 104.53.202.214        429
# 72.181.110.80         420
# 70.123.231.211        417
# 173.175.122.123       406
# 67.11.134.242         405
# 99.98.36.168          391
#                     ...
# 45.56.151.121           1
# 172.5.98.113            1
# 172.58.70.192           1
# 104.237.80.44           1
# 107.77.94.33            1
# 173.239.232.37          1
# 107.77.105.20           1
# 70.114.21.86            1
# 136.50.0.214            1
# 37.60.189.18            1
# 99.203.27.178           1
# 66.102.6.171            1
# 99.203.26.97            1
# 64.132.225.203          1
# 66.69.37.36             1
# 172.56.6.109            1
# 24.243.59.164           1
# 99.203.155.25           1
# 72.181.120.73           1
# 172.58.103.50           1
# 72.190.182.108          1
# 137.254.7.169           1
# 104.176.91.161          1
# 67.198.116.192          1
# 172.58.109.220          1
# 205.251.148.178         1
# 172.56.6.31             1
# 107.77.100.89           1
# 172.56.6.73             1
# 104.237.80.93           1
# Name: ip_address, Length: 1731, dtype: int64

# %% [markdown]
# This is where I'm using ipino to try to read the ipaddress. It works when I use the default that tells me the stats on MY ip address.

# %%
# import re
# import json
# from urllib.request import urlopen

url = 'http://ipinfo.io/json'
response = urlopen(url)
data = json.load(response)

IP=data['ip']
org=data['org']
loc=data['loc']
city = data['city']
country=data['country']
region=data['region']

print('Your IP detail\n ')
print('IP : {4} \nRegion : {1} \nCountry : {2} \nCity : {3} \nLoc : {5} \nOrg : {0}'.format(org,region,country,city,IP,loc))
# Out:
# Your IP detail
#
# IP : 97.105.19.58
# Region : Texas
# Country : US
# City : San Antonio
# Loc : 29.4241,-98.4936
# Org : AS11427 Charter Communications Inc

# %%
# import re
# import json
# from urllib.request import urlopen

url = 'http://ipinfo.io/json'
ip='95.31.18.119'
response = urlopen(url)
data = json.load(response)

IP=data['ip']
org=data['org']
loc=data['loc']
city = data['city']
country=data['country']
region=data['region']

print('Your IP detail\n ')
print('IP : {4} \nRegion : {1} \nCountry : {2} \nCity : {3} \nLoc : {5} \nOrg : {0}'.format(org,region,country,city,IP,loc))
# Out:
# Your IP detail
#
# IP : 97.105.19.58
# Region : Texas
# Country : US
# City : San Antonio
# Loc : 29.4241,-98.4936
# Org : AS11427 Charter Communications Inc

# %% [markdown]
# I couldn't figure out how to pass the ipaddress as an argument, so I found this code, but couldn't figure out how to make it work...

# %%
# import ipinfo
access_token = '123456789abc'
handler = ipinfo.getHandler(access_token)
ip_address = '216.239.36.21'
details = handler.getDetails(ip_address)
details.city
details.loc
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-28-63f2e8dd879b> in <module>
#       3 handler = ipinfo.getHandler(access_token)
#       4 ip_address = '216.239.36.21'
# ----> 5 details = handler.getDetails(ip_address)
#       6 details.city
#       7 details.loc
#
# /usr/local/anaconda3/lib/python3.7/site-packages/ipinfo/handler.py in getDetails(self, ip_address)
#      44     def getDetails(self, ip_address=None):
#      45         """Get details for specified IP address as a Details object."""
# ---> 46         raw_details = self._requestDetails(ip_address)
#      47         raw_details['country_name'] = self.countries.get(raw_details.get('country'))
#      48         raw_details['ip_address'] = ipaddress.ip_address(raw_details.get('ip'))
#
# /usr/local/anaconda3/lib/python3.7/site-packages/ipinfo/handler.py in _requestDetails(self, ip_address)
#      60             if response.status_code == 429:
#      61                 raise RequestQuotaExceededError()
# ---> 62             response.raise_for_status()
#      63             self.cache[ip_address] = response.json()
#      64
#
# /usr/local/anaconda3/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     938
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#     942     def close(self):
#
# HTTPError: 403 Client Error: Forbidden for url: https://ipinfo.io/216.239.36.21

# %% [markdown]
# # import file with cohort info

# %%
cohorts = pd.read_csv('./cohort_data.csv')     
cohorts.set_index('id', inplace=True)
cohorts
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-114e499bd928> in <module>
# ----> 1 cohorts = pd.read_csv('./cohort_data.csv')
#       2 cohorts.set_index('id', inplace=True)
#       3 cohorts
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'./cohort_data.csv' does not exist

# %% [markdown]
# Count number of unique values.

# %%
df.nunique()
# Out:
# date            432
# time          55696
# stuff           998
# id              398
# cohort           27
# ip_address     1731
# dtype: int64

# %%
df.describe()
# Out:
#                   id         cohort
# count  233527.000000  233527.000000
# mean      191.156149      21.687788
# std       111.150132       7.963288
# min         1.000000       0.000000
# 25%       107.000000      22.000000
# 50%       202.000000      24.000000
# 75%       277.000000      26.000000
# max       398.000000      31.000000

# %%
df.status.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-8c2c238df762> in <module>
# ----> 1 df.status.value_counts()
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'status'

# %% [markdown]
# Filtered the dataframe down to only cohort == 24.

# %%
df_24 = df[df['cohort'] == 24]

# %% [markdown]
# Creating a new dataframe with only ip_address and counts.

# %%
df_24 = df_24['ip_address'].value_counts().reset_index()
df_24.columns = ['ip_address', 'count']

# %%
df_24.tail(257)
# Out:
#           ip_address  count
# 0       97.105.19.58  16256
# 1       97.105.19.61  10218
# 2    192.171.117.210   1129
# 3      72.181.104.64    599
# 4    170.248.173.245    451
# 5      68.206.106.64    446
# 6     104.53.202.214    429
# 7     99.158.248.205    362
# 8       72.191.31.35    339
# 9       67.11.175.66    320
# 10      66.69.49.204    283
# 11     72.178.123.71    270
# 12    108.199.115.75    264
# 13   170.248.173.247    239
# 14     70.121.204.76    232
# 15     99.101.216.49    223
# 16     173.173.47.94    197
# 17   170.248.173.246    179
# 18   173.174.196.212    138
# 19      67.11.172.66    131
# 20    108.66.243.159    127
# 21     45.31.213.223    103
# 22    99.132.129.169     97
# 23    99.158.247.252     97
# 24     107.204.53.24     90
# 25    70.123.203.131     77
# 26       66.69.50.45     66
# 27    70.121.185.146     66
# 28    167.24.104.150     66
# 29   199.193.220.210     58
# ..               ...    ...
# 106   107.77.105.117      2
# 107    172.58.109.83      2
# 108    172.58.109.48      2
# 109     107.77.80.83      2
# 110     107.77.66.26      2
# 111  166.251.109.229      2
# 112  108.220.101.224      2
# 113     104.63.15.53      2
# 114    107.77.105.78      2
# 115    99.203.27.241      2
# 116   166.137.136.55      1
# 117     65.36.106.75      1
# 118    107.77.197.78      1
# 119    172.58.99.179      1
# 120    72.181.100.92      1
# 121    45.31.212.160      1
# 122     72.181.37.22      1
# 123    99.203.26.118      1
# 124   107.77.220.108      1
# 2018-01-26 09:56:02     8.0  97.105.19.61
# 2018-01-26 09:56:05     8.0  97.105.19.61
# 2018-01-26 09:56:06     8.0  97.105.19.61
# 2018-01-26 09:56:24    22.0  97.105.19.61
# 2018-01-26 09:56:41    22.0  97.105.19.61
# 2018-01-26 09:56:46    22.0  97.105.19.61
# 2018-01-26 09:56:48    22.0  97.105.19.61
# 2018-01-26 09:56:59    22.0  97.105.19.61
# 2018-01-26 09:58:26    22.0  97.105.19.61
# 2018-01-26 09:59:22    22.0  97.105.19.61
# 2018-01-26 10:00:02    22.0  97.105.19.61
# 2018-01-26 10:00:37    22.0  97.105.19.61
# 2018-01-26 10:00:39    22.0  97.105.19.61
# 2018-01-26 10:00:44    22.0  97.105.19.61
# 2018-01-26 10:00:49    22.0  97.105.19.61
# 2018-01-26 10:00:57    22.0  97.105.19.61
# 2018-01-26 10:01:12    22.0  97.105.19.61
# 2018-01-26 10:02:02    22.0  97.105.19.61
# 2018-01-26 10:02:21    22.0  97.105.19.61

# %% [markdown]
# Creating a dataframe with probabilities that each ip address will be used.

# %%
ip_df = pd.DataFrame(df.ip.value_counts(dropna=False)).reset_index().\
                rename(index=str, columns={'index': 'ip', 'ip': 'ip_count'})
ip_df2 = pd.DataFrame(df.ip.value_counts(dropna=False)/df.ip.count()).reset_index().\
                rename(index=str, columns={'index': 'ip', 'ip': 'ip_proba'})
ip_df = ip_df.merge(ip_df2)


# see those where rate < 1% 
ip_df[ip_df.ip_proba < .01]
# Out:
#                    ip  ip_count  ip_proba
# 3     173.174.211.206      1019  0.004364
# 4        66.69.62.219       934  0.004000
# 5       72.181.104.64       865  0.003704
# 6       216.1.153.162       790  0.003383
# 7         67.11.239.2       749  0.003207
# 8       66.69.108.117       666  0.002852
# 9     170.248.173.245       661  0.002831
# 10       67.10.161.55       651  0.002788
# 11       70.118.8.243       614  0.002629
# 12       70.121.163.5       565  0.002419
# 13      76.185.182.91       564  0.002415
# 14       76.204.31.63       549  0.002351
# 15        24.243.8.81       539  0.002308
# 16      72.191.50.176       523  0.002240
# 17     173.173.113.51       512  0.002192
# 18      108.65.244.91       506  0.002167
# 19    173.174.253.193       506  0.002167
# 20    170.248.173.247       467  0.002000
# 21      104.53.201.99       447  0.001914
# 22      68.206.106.64       446  0.001910
# 23     76.185.131.226       432  0.001850
# 24     104.53.202.214       429  0.001837
# 25      72.181.110.80       420  0.001799
# 26     70.123.231.211       417  0.001786
# 27    173.175.122.123       406  0.001739
# 28      67.11.134.242       405  0.001734
# 29       99.98.36.168       391  0.001674
# 30       67.10.174.56       389  0.001666
# 31     72.190.161.136       385  0.001649
# 32      107.204.132.6       380  0.001627
# ...               ...       ...       ...
# 1701    45.56.151.121         1  0.000004
# 1702     172.5.98.113         1  0.000004
# 1703    172.58.70.192         1  0.000004
# 1704    104.237.80.44         1  0.000004
# 1705     107.77.94.33         1  0.000004
# 1706   173.239.232.37         1  0.000004
# 1707    107.77.105.20         1  0.000004
# 1708     70.114.21.86         1  0.000004
# 1709     136.50.0.214         1  0.000004
# 1710     37.60.189.18         1  0.000004
# 1711    99.203.27.178         1  0.000004
# 1712     66.102.6.171         1  0.000004
# 1713     99.203.26.97         1  0.000004
# 1714   64.132.225.203         1  0.000004
# 1715      66.69.37.36         1  0.000004
# 1716     172.56.6.109         1  0.000004
# 1717    24.243.59.164         1  0.000004
# 1718    99.203.155.25         1  0.000004
# 1719    72.181.120.73         1  0.000004
# 1720    172.58.103.50         1  0.000004
# 1721   72.190.182.108         1  0.000004
# 1722    137.254.7.169         1  0.000004
# 1723   104.176.91.161         1  0.000004
# 1724   67.198.116.192         1  0.000004
# 1725   172.58.109.220         1  0.000004
# 1726  205.251.148.178         1  0.000004
# 1727      172.56.6.31         1  0.000004
# 1728    107.77.100.89         1  0.000004
# 1729      172.56.6.73         1  0.000004
# 1730    104.237.80.93         1  0.000004
#
# [1728 rows x 3 columns]

# %% [markdown]
# Only interested in the low probability ip addresses. Had to weed down to ip_df.ip_proba < 0.000005 to weed down the count significantly. That gave 256 rows.

# %%
sm_chance = ip_df[ip_df.ip_proba < 0.000005]
sm_chance.shape
# Out:
# (256, 3)

# %% [markdown]
# My graph is very pretty, but not at all meaningful.

# %%
print(len(sm_chance))

print(sm_chance.tail(10))


plt.figure(figsize=(12, 4))
splot = sns.barplot(data=sm_chance, x = 'ip', y = 'ip_count', ci = None)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', xytext = (0, 10), 
                   textcoords = 'offset points'
                   )
    plt.xticks(rotation='vertical')
# Out:
# 256
#                    ip  ip_count  ip_proba
# 1721   72.190.182.108         1  0.000004
# 1722    137.254.7.169         1  0.000004
# 1723   104.176.91.161         1  0.000004
# 1724   67.198.116.192         1  0.000004
# 1725   172.58.109.220         1  0.000004
# 1726  205.251.148.178         1  0.000004
# 1727      172.56.6.31         1  0.000004
# 1728    107.77.100.89         1  0.000004
# 1729      172.56.6.73         1  0.000004
# 1730    104.237.80.93         1  0.000004

# %% [markdown]
# ### Detecting anomalies by establishing a baseline and evaluate as new data arrives
# ##### Establish baseline

# %%
df.columns
# Out:
# Index(['date', 'time', 'stuff', 'id', 'cohort', 'ip'], dtype='object')

# %% [markdown]
# Dropping date and time and selecting a range of dates.

# %%
train = df['2018-01-26 09:55:03':'2019-01-26 09:55:03'][['stuff', 'id', 'cohort', 'ip']]

# %% [markdown]
# ##### Compute probabilities based on train sample

# %%
ip_df = pd.DataFrame(train.ip.value_counts(dropna=False)/train.ip.count()).reset_index().\
                rename(index=str, columns={'index': 'ip', 'ip': 'ip_proba'})

# %% [markdown]
# ##### Merge probabilities with all data (train + new data)
# - Where the ip address is new, i.e. not seen in the training dataset, fill the probability with a value of 0.

# %%
df = df.reset_index().merge(ip_df, on=['ip'], how='left').fillna(value=0).set_index('timestamp')
df.ip.value_counts()
# Out:
# 97.105.19.58       105645
# 97.105.19.61        61662
# 192.171.117.210      5966
# 173.174.211.206      1019
# 66.69.62.219          934
# 72.181.104.64         865
# 216.1.153.162         790
# 67.11.239.2           749
# 66.69.108.117         666
# 170.248.173.245       661
# 67.10.161.55          651
# 70.118.8.243          614
# 70.121.163.5          565
# 76.185.182.91         564
# 76.204.31.63          549
# 24.243.8.81           539
# 72.191.50.176         523
# 173.173.113.51        512
# 108.65.244.91         506
# 173.174.253.193       506
# 170.248.173.247       467
# 104.53.201.99         447
# 68.206.106.64         446
# 76.185.131.226        432
# 104.53.202.214        429
# 72.181.110.80         420
# 70.123.231.211        417
# 173.175.122.123       406
# 67.11.134.242         405
# 99.98.36.168          391
#                     ...
# 45.56.151.121           1
# 172.5.98.113            1
# 172.58.70.192           1
# 104.237.80.44           1
# 107.77.94.33            1
# 173.239.232.37          1
# 107.77.105.20           1
# 70.114.21.86            1
# 136.50.0.214            1
# 37.60.189.18            1
# 99.203.27.178           1
# 66.102.6.171            1
# 99.203.26.97            1
# 64.132.225.203          1
# 66.69.37.36             1
# 172.56.6.109            1
# 24.243.59.164           1
# 99.203.155.25           1
# 72.181.120.73           1
# 172.58.103.50           1
# 72.190.182.108          1
# 137.254.7.169           1
# 104.176.91.161          1
# 67.198.116.192          1
# 172.58.109.220          1
# 205.251.148.178         1
# 172.56.6.31             1
# 107.77.100.89           1
# 172.56.6.73             1
# 104.237.80.93           1
# Name: ip, Length: 1731, dtype: int64

# %% [markdown]
# ### Conditional Probabilities: probabilities using 2 discrete variables
# ##### Probability of Status given IP Address:
# If we are looking for an unexpected status (like authentication failure) from a known/common IP address.

# %%
train.columns
# Out:
# Index(['stuff', 'id', 'cohort', 'ip'], dtype='object')

# %%
ip_probs = train.groupby('ip').size().div(len(df))

status_given_ip = pd.DataFrame(train.groupby(['ip', 'cohort']).\
                               size().div(len(train)).\
                               div(ip_probs, 
                                   axis=0, 
                                   level='ip').\
                               reset_index().\
                               rename(index=str, 
                                      columns={0: 'proba_status_given_ip'})
                              )

# %%
ip_status_count = pd.DataFrame(train.groupby(['ip', 'cohort'])['stuff'].\
                                count().reset_index().\
                                rename(index=str, 
                                       columns={'stuff': 'ip_status_count'}))


ip_status = status_given_ip.merge(ip_status_count)
ip_status.head()
# Out:
#                 ip  cohort  proba_status_given_ip  ip_status_count
# 0    100.35.67.162    21.0               1.264283               11
# 1     104.1.46.153    23.0               1.264283               11
# 2   104.12.206.124     0.0               1.264283               42
# 3   104.129.18.241    25.0               1.264283                3
# 4  104.129.196.183    22.0               1.264283                2

# %% [markdown]
# ##### Add these probabilities to original events to detect anomalous events

# %%
df = df.reset_index().merge(ip_status, on=['ip', 'cohort'], how='left').fillna(value=0).set_index('timestamp')

# %%
df.head(2)
# Out:
#                            date      time      stuff  id  cohort  \
# timestamp
# 2018-01-26 09:55:03  2018-01-26  09:55:03  home_page   1     8.0
# 2018-01-26 09:56:02  2018-01-26  09:56:02    java-ii   1     8.0
#
#                                ip  ip_proba  proba_status_given_ip  \
# timestamp
# 2018-01-26 09:55:03  97.105.19.61   0.33383               0.020831
# 2018-01-26 16:00:29    22.0  209.205.123.242  0.000027               1.264283
#
#                      ip_status_count
# timestamp
# 2018-01-26 10:59:02             36.0
# 2018-01-26 10:59:06             36.0
# 2018-01-26 12:20:36              5.0
# 2018-01-26 12:20:41              5.0
# 2018-01-26 16:00:29              5.0

# %%
plt.scatter(df.proba_status_given_ip, df.ip_proba)

# %%
plt.scatter(sm_proba.proba_status_given_ip, sm_proba.ip_proba)

# %% [markdown]
# # Detecting Anomalies of Continuous Variables with Time Series Using Statistical Methods

# %% [markdown]
# # *Pick a cohort and run this time series analysis on it*
# ## Time series + EMA
# ### Discover users who are accessing our curriculum pages way beyond the end of their codeup time. What would the dataframe look like? Use time series method for detecting anomalies, like exponential moving average with %b.
#
#
#
# ### Statistical Methods
# - Flag the data points that deviate from the expected, based on the statistical properties, such as mean, median, mode, and quantiles.
#
# - You could define an anomalous data point as one that deviates by a certain standard deviation from the mean.
#
# - You could use a simple or exponential moving average to smooth short-term fluctuations and highlight long-term ones.
#
# - This method is challenging with really noisy data.
#
# ### Anomalies in the amount of data consumed over time

# %%
from __future__ import division
import itertools
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from numpy import linspace, loadtxt, ones, convolve
from sklearn.ensemble import IsolationForest
import numpy as np
import pandas as pd
import collections
import math
from sklearn import metrics
from random import randint
from matplotlib import style
import seaborn as sns
# style.use('fivethirtyeight')
# %matplotlib inline

def evaluate(actual, predictions, output=True):
    mse = metrics.mean_squared_error(actual, predictions)
    rmse = math.sqrt(mse)

    if output:
        print('MSE:  {}'.format(mse))
        print('RMSE: {}'.format(rmse))
    else:
        return mse, rmse    

def plot_and_eval(predictions, actual, metric_fmt='{:.2f}', linewidth=4):
    if type(predictions) is not list:
        predictions = [predictions]

    plt.figure(figsize=(16, 8))
    plt.plot(train,label='Train')
    plt.plot(test, label='Test')

    for yhat in predictions:
        mse, rmse = evaluate(actual, yhat, output=False)        
        label = f'{yhat.name}'
        if len(predictions) > 1:
            label = f'{label} -- MSE: {metric_fmt} RMSE: {metric_fmt}'.format(mse, rmse)
        plt.plot(yhat, label=label, linewidth=linewidth)

    if len(predictions) == 1:
        label = f'{label} -- MSE: {metric_fmt} RMSE: {metric_fmt}'.format(mse, rmse)
        plt.title(label)

    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# #### Wrangle Data
# ##### Acquire

# %%
colnames=['date', 'time', 'stuff', 'id', 'cohort', 'ip_address']
df = pd.read_csv('./anonymized-curriculum-access.txt',          
                 engine='python',
                 header=None,
                 index_col=False,
                 names=colnames,
                 sep=' ',
                 na_values='"-"'
)

# %%
df.head()
# Out:
#          date      time                                stuff  id  cohort  \
# 0  2018-01-26  09:55:03                                    /   1     8.0
# 1  2018-01-26  09:56:02                              java-ii   1     8.0
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming   1     8.0
# 3  2018-01-26  09:56:06   slides/object_oriented_programming   1     8.0
# 4  2018-01-26  09:56:24            javascript-i/conditionals   2    22.0
#
#      ip_address
# 0  97.105.19.61
# 1  97.105.19.61
# 2  97.105.19.61
# 3  97.105.19.61
# 4  97.105.19.61

# %%
df.isna().sum()
# Out:
# date              0
# time              0
# stuff             0
# id                0
# cohort        14458
# ip_address        0
# dtype: int64

# %%
df.cohort.fillna(0, inplace=True)

# %%
df.isna().sum()
# Out:
# date          0
# time          0
# stuff         0
# id            0
# cohort        0
# ip_address    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233528 entries, 0 to 233527
# Data columns (total 6 columns):
# date          233528 non-null object
# time          233528 non-null object
# stuff         233528 non-null object
# id            233528 non-null int64
# cohort        233528 non-null float64
# ip_address    233528 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 10.7+ MB

# %% [markdown]
# ##### Parse Datetime

# %%
df.head()
# Out:
#          date      time                                stuff  id  cohort  \
# 0  2018-01-26  09:55:03                                    /   1     8.0
# 1  2018-01-26  09:56:02                              java-ii   1     8.0
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming   1     8.0
# 3  2018-01-26  09:56:06   slides/object_oriented_programming   1     8.0
# 4  2018-01-26  09:56:24            javascript-i/conditionals   2    22.0
#
#      ip_address
# 0  97.105.19.61
# 1  97.105.19.61
# 2  97.105.19.61
# 3  97.105.19.61
# 4  97.105.19.61

# %%
df['timestamp'] = df.date + ' ' + df.time
df.timestamp = pd.to_datetime(df['timestamp'])
df.head()
# Out:
#          date      time                                stuff  id  cohort  \
# 0  2018-01-26  09:55:03                                    /   1     8.0
# 1  2018-01-26  09:56:02                              java-ii   1     8.0
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming   1     8.0
# 3  2018-01-26  09:56:06   slides/object_oriented_programming   1     8.0
# 4  2018-01-26  09:56:24            javascript-i/conditionals   2    22.0
#
#      ip_address           timestamp
# 0  97.105.19.61 2018-01-26 09:55:03
# 1  97.105.19.61 2018-01-26 09:56:02
# 2  97.105.19.61 2018-01-26 09:56:05
# 3  97.105.19.61 2018-01-26 09:56:06
# 4  97.105.19.61 2018-01-26 09:56:24

# %%
df = df.set_index('timestamp')
df.head()
# Out:
#                            date      time  \
# timestamp
# 2018-01-26 09:55:03  2018-01-26  09:55:03
# 2018-01-26 09:56:02  2018-01-26  09:56:02
# 2018-01-26 09:56:05  2018-01-26  09:56:05
# 2018-01-26 09:56:06  2018-01-26  09:56:06
# 2018-01-26 09:56:24  2018-01-26  09:56:24
#
#                                                    stuff  id  cohort  \
# timestamp
# 2018-01-26 09:55:03                                    /   1     8.0
# 2018-01-26 09:56:02                              java-ii   1     8.0
# 2018-01-26 09:56:05  java-ii/object-oriented-programming   1     8.0
# 2018-01-26 09:56:06   slides/object_oriented_programming   1     8.0
# 2018-01-26 09:56:24            javascript-i/conditionals   2    22.0
#
#                        ip_address
# timestamp
# 2018-01-26 09:55:03  97.105.19.61
# 2018-01-26 09:56:02  97.105.19.61
# 2018-01-26 09:56:05  97.105.19.61
# 2018-01-26 09:56:06  97.105.19.61
# 2018-01-26 09:56:24  97.105.19.61

# %% [markdown]
# ##### Clean up text

# %%
df.replace(regex=r'^/$', value='home_page', inplace=True)

# %%
maxcount = 0
for i, command in enumerate(df.stuff):
    if len(command.split('/')) > maxcount:
        maxcount = len(command.split('/'))
        print('maxcount: ', maxcount)
        print(command)
print('final maxcount is ', maxcount)
# Out:
# maxcount:  1
# home_page
# maxcount:  2
# java-ii/object-oriented-programming
# maxcount:  3
# javascript-i/introduction/working-with-data-types-operators-and-variables
# maxcount:  4
# appendix/further-reading/javascript/hoisting.html
# maxcount:  6
# content/laravel/intro/gitbook/images/favicon.ico
# maxcount:  7
# content/appendix/postwork/basic_challenges/gitbook/images/favicon.ico
# maxcount:  8
# cohorts/%7Bid%7D/grades.csvhttp://tools.codeup.com/cohorts/26/grades.csv
# final maxcount is  8

# %%
df[df.stuff == 'cohorts/%7Bid%7D/grades.csvhttp://tools.codeup.com/cohorts/26/grades.csv']
# Out:
#                            date      time  \
# timestamp
# 2019-01-11 11:51:19  2019-01-11  11:51:19
#
#                                                                  stuff  id  \
# timestamp
# 2019-01-11 11:51:19  cohorts/%7Bid%7D/grades.csvhttp://tools.codeup...  64
#
#                      cohort    ip_address
# timestamp
# 2019-01-11 11:51:19    28.0  70.118.8.243

# %%
df = df[df.stuff != 'cohorts/%7Bid%7D/grades.csvhttp://tools.codeup.com/cohorts/26/grades.csv']
df[df.stuff == 'cohorts/%7Bid%7D/grades.csvhttp://tools.codeup.com/cohorts/26/grades.csv']
# Out:
# Empty DataFrame
# Columns: [date, time, stuff, id, cohort, ip_address]
# Index: []

# %%
maxcount = 0
for i, command in enumerate(df.stuff):
    if len(command.split('/')) > maxcount:
        maxcount = len(command.split('/'))
        print('maxcount: ', maxcount)
        print(command)
print('final maxcount is ', maxcount)
# Out:
# maxcount:  1
# home_page
# maxcount:  2
# java-ii/object-oriented-programming
# maxcount:  3
# javascript-i/introduction/working-with-data-types-operators-and-variables
# maxcount:  4
# appendix/further-reading/javascript/hoisting.html
# maxcount:  6
# content/laravel/intro/gitbook/images/favicon.ico
# maxcount:  7
# content/appendix/postwork/basic_challenges/gitbook/images/favicon.ico
# final maxcount is  7

# %%
df['stuff'] = df.stuff.str.replace(r'\?page=[0-9]+', '', regex=True)

df.head()
# Out:
#                            date      time  \
# timestamp
# 2018-01-26 09:55:03  2018-01-26  09:55:03
# 2018-01-26 09:56:02  2018-01-26  09:56:02
# 2018-01-26 09:56:05  2018-01-26  09:56:05
# 2018-01-26 09:56:06  2018-01-26  09:56:06
# 2018-01-26 09:56:24  2018-01-26  09:56:24
#
#                                                    stuff  id  cohort  \
# timestamp
# 2018-01-26 09:55:03                            home_page   1     8.0
# 2018-01-26 09:56:02                              java-ii   1     8.0
# 2018-01-26 09:56:05  java-ii/object-oriented-programming   1     8.0
# 2018-01-26 09:56:06   slides/object_oriented_programming   1     8.0
# 2018-01-26 09:56:24            javascript-i/conditionals   2    22.0
#
#                        ip_address
# timestamp
# 2018-01-26 09:55:03  97.105.19.61
# 2018-01-26 09:56:02  97.105.19.61
# 2018-01-26 09:56:05  97.105.19.61
# 2018-01-26 09:56:06  97.105.19.61
# 2018-01-26 09:56:24  97.105.19.61

# %%
df.describe()
# Out:
#                   id         cohort
# count  233527.000000  233527.000000
# mean      191.156149      21.687788
# std       111.150132       7.963288
# min         1.000000       0.000000
# 25%       107.000000      22.000000
# 50%       202.000000      24.000000
# 75%       277.000000      26.000000
# max       398.000000      31.000000

# %% [markdown]
# 1. resample to 30 minute intervals taking max of size
# 2. fill in missing datetimestamps (those not present because no data was captured during that time. We want to have continuous time and those time periods filled with 0)

# %%
df2 = df.copy()
df = df[df['cohort'] == 24]
df = df.drop(columns=(['date', 'time']))

# %%
df.index.date
# Out:
# array([datetime.date(2018, 5, 29), datetime.date(2018, 5, 29),
#        datetime.date(2018, 5, 29), ..., datetime.date(2019, 3, 29),
#        datetime.date(2019, 3, 29), datetime.date(2019, 3, 29)],
#       dtype=object)

# %%
my_datetime_fmt = mdates.DateFormatter('%m-%d %H:%T')

df_ts_size = df['cohort'].resample('30T').max()

idx = pd.date_range(
    df_ts_size.sort_index().index.min(), 
    df_ts_size.sort_index().index.max(),
    freq='30min'
)

df_ts_size = df_ts_size.reindex(idx, fill_value=0).fillna(value=0)

# %% [markdown]
# ##### Split into train/test

# %%
start_date_train = df_ts_size.head(1).index[0]
end_date_train = '2018-09-01 23:30:00'
start_date_test = '2018-09-02 00:00:00'
end_date_test = '2018-12-15 00:00:00'

train = df_ts_size[:end_date_train]
test = df_ts_size[start_date_test:end_date_test]

# %%
train.head().append(train.tail())
# Out:
# 2018-05-29 14:30:00    24.0
# 2018-05-29 15:00:00    24.0
# 2018-05-29 15:30:00    24.0
# 2018-05-29 16:00:00     0.0
# 2018-05-29 16:30:00     0.0
# 2018-09-01 21:30:00    24.0
# 2018-09-01 22:00:00     0.0
# 2018-09-01 22:30:00     0.0
# 2018-09-01 23:00:00     0.0
# 2018-09-01 23:30:00     0.0
# Name: cohort, dtype: float64

# %%
plt.figure(figsize=(12, 8))
plt.plot(train)
plt.plot(test)
plt.show()

# %% [markdown]
# ##### SMA - Simple Moving Average

# %%
# Calculating the short-window simple moving average
short_rolling = train.rolling(window=12).mean()

# Calculating the long-window simple moving average
long_rolling = train.rolling(window=24).mean()

# %% [markdown]
# ##### Plot the 2 window sizes for the SMA

# %%
fig, ax = plt.subplots(figsize=(12,4))

ax.plot(train.index, 
        train,
        label='Size (MB)')

ax.plot(short_rolling.index, 
        short_rolling, 
        label = '6-Hour SMA')
ax.plot(long_rolling.index, 
        long_rolling, 
        label = '12-Hour SMA')

ax.legend(loc='best')
ax.set_ylabel('Size (MB)')
# ax.xaxis.(rotate=90)
# ax.xaxis.set_major_formatter(my_datetime_fmt)
# Out:
# Text(0, 0.5, 'Size (MB)')

# %% [markdown]
# ##### Compute the Exponential Moving Average

# %%
# Using Pandas to calculate a 2 hour span EMA. 
# adjust=False specifies that we are interested in the 
# recursive calculation mode.
ema_short = train.ewm(span=12, adjust=False).mean()
ema_short[0:3]

ema_long = train.ewm(span=24, adjust=False).mean()
ema_long[0:3]
# Out:
# 2018-05-29 14:30:00    24.0
# 2018-05-29 15:00:00    24.0
# 2018-05-29 15:30:00    24.0
# Freq: 30T, Name: cohort, dtype: float64

# %% [markdown]
# ##### Compare SMA with EMA

# %%
fig, ax = plt.subplots(figsize=(12,4))

ax.plot(train.index, 
        train,
        label='Size (MB)')

ax.plot(short_rolling.index, 
        short_rolling, 
        label = '6-Hour SMA')
ax.plot(long_rolling.index, 
        ema_short, 
        label = 'Span 6-Hour EMA')
ax.plot(long_rolling.index, 
        long_rolling, 
        label = '12-Hour SMA')
ax.plot(long_rolling.index, 
        ema_long, 
        label = 'Span 12-Hour EMA')

ax.legend(loc='best')
ax.set_ylabel('Size (MB)')

yhat = pd.DataFrame(dict(actual=test))

# %% [markdown]
# #### Forecast using the EMA

# %%
# periods = 24
yhat['moving_avg_forecast'] = ema_long.iloc[-1]

# %% [markdown]
# ##### Compute the '%b' for each record

# %%
# compute the absolute error:
yhat['error'] = abs(yhat.actual - yhat.moving_avg_forecast)

# compute the mean of the absolute error:
# yhat.error.median()

# compute upper band and lower band using IQR with weight of 3

q3 = yhat.error.describe().loc['75%']
q1 = yhat.error.describe().loc['25%']

# adding .1 to the IQR so the we don't end up with a denominator of 0. 
ub = q3 + 3*(q3-q1+.1)
lb = q1 - 3*(q3-q1+.1)

yhat['pct_b'] = (yhat.actual-lb)/(ub-lb)

# %%
# Maggie's code to find outliers:
# span = 24
# ema_long = train.ewm(span=span, adjust=False).mean()
# midband = ema_long[-1]
# ub = midband + ema_long[-24:-1].std()*3
# lb = midband - ema_long[-24:-1].std()*3

# yhat['moving_avg_forecast'] = midband

# %% [markdown]
# ##### Extract the anomalies

# %%
yhat[yhat.pct_b > 1]
# Out:
#                      actual  moving_avg_forecast     error      pct_b
# 2018-09-02 10:30:00    24.0              2.63083  21.36917  36.115283
# 2018-09-02 13:00:00    24.0              2.63083  21.36917  36.115283
# 2018-09-02 13:30:00    24.0              2.63083  21.36917  36.115283
# 2018-09-02 14:00:00    24.0              2.63083  21.36917  36.115283
# 2018-09-02 14:30:00    24.0              2.63083  21.36917  36.115283
# 2018-09-02 15:00:00    24.0              2.63083  21.36917  36.115283
# 2018-09-02 17:00:00    24.0              2.63083  21.36917  36.115283
# 2018-09-02 18:30:00    24.0              2.63083  21.36917  36.115283
# 2018-09-02 19:00:00    24.0              2.63083  21.36917  36.115283
# 2018-09-02 23:30:00    24.0              2.63083  21.36917  36.115283
# 2018-09-03 00:00:00    24.0              2.63083  21.36917  36.115283
# 2018-09-03 11:00:00    24.0              2.63083  21.36917  36.115283
# 2018-09-03 11:30:00    24.0              2.63083  21.36917  36.115283
# 2018-09-03 13:30:00    24.0              2.63083  21.36917  36.115283
# 2018-09-03 14:00:00    24.0              2.63083  21.36917  36.115283
# 2018-09-03 14:30:00    24.0              2.63083  21.36917  36.115283
# 2018-09-03 15:30:00    24.0              2.63083  21.36917  36.115283
# 2018-09-03 16:00:00    24.0              2.63083  21.36917  36.115283
